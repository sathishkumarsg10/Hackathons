# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
train = pd.read_csv(os.getcwd() + '/train.csv')
test = pd.read_csv(os.getcwd() + '/test.csv')

# %%
train.head()
# Out:
#              Artist Name                             Track Name  Popularity  \
# 0             Bruno Mars  That's What I Like (feat. Gucci Mane)        60.0
# 1                 Boston                           Hitch a Ride        54.0
# 2          The Raincoats                     No Side to Fall In        35.0
# 3                   Deno             Lingo (feat. J.I & Chunkz)        66.0
# 4  Red Hot Chili Peppers      Nobody Weird Like Me - Remastered        53.0
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.854   0.564   1.0    -4.964     1       0.0485      0.017100
# 1         0.382   0.814   3.0    -7.230     1       0.0406      0.001100
# 2         0.434   0.614   6.0    -8.334     1       0.0525      0.486000
# 3         0.853   0.597  10.0    -6.528     0       0.0555      0.021200
# 4         0.167   0.975   2.0    -4.279     1       0.2160      0.000169
#
#    instrumentalness  liveness  valence    tempo  duration_in min/ms  \
# 0               NaN    0.0849   0.8990  134.071            234596.0
# 1          0.004010    0.1010   0.5690  116.454            251733.0
# 2          0.000196    0.3940   0.7870  147.681            109667.0
# 3               NaN    0.1220   0.5690  107.033            173968.0
# 4          0.016100    0.1720   0.0918  199.060            229960.0
#
#    time_signature  Class
# 0               4      5
# 1               4     10
# 2               4      6
# 3               4      5
# 4               4     10

# %%
train['flag'] = 'train'
test['flag'] = 'test'
data = pd.concat([train, test], ignore_index = False)

# %%
import seaborn as sns

# %%
columns  = ['Popularity', 'danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo',
       'duration_in min/ms', 'time_signature']

# %%
plt.figure(figsize = (20,40))
for i in range(len(columns)):
    plt.subplot(6, 3, i+1)
    sns.histplot(data = train, x = columns[i])
plt.show()

# %%
plt.figure(figsize = (20,40))
for i in range(len(columns)):
    plt.subplot(6, 3, i+1)
    sns.histplot(data = test, x = columns[i])
plt.show()

# %%
train.columns
# Out:
# Index(['Artist Name', 'Track Name', 'Popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_in min/ms', 'time_signature', 'Class'],
#       dtype='object')

# %%
train.time_signature.value_counts()
# Out:
# 4    16451
# 3     1228
# 5      203
# 1      114
# Name: time_signature, dtype: int64

# %%
test.time_signature.value_counts()
# Out:
# 4    7046
# 3     541
# 5      72
# 1      53
# 0       1
# Name: time_signature, dtype: int64

# %%
train.head()
# Out:
#              Artist Name                             Track Name  Popularity  \
# 0             Bruno Mars  That's What I Like (feat. Gucci Mane)        60.0
# 1                 Boston                           Hitch a Ride        54.0
# 2          The Raincoats                     No Side to Fall In        35.0
# 3                   Deno             Lingo (feat. J.I & Chunkz)        66.0
# 4  Red Hot Chili Peppers      Nobody Weird Like Me - Remastered        53.0
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.854   0.564   1.0    -4.964     1       0.0485      0.017100
# 1         0.382   0.814   3.0    -7.230     1       0.0406      0.001100
# 2         0.434   0.614   6.0    -8.334     1       0.0525      0.486000
# 3         0.853   0.597  10.0    -6.528     0       0.0555      0.021200
# 4         0.167   0.975   2.0    -4.279     1       0.2160      0.000169
#
#    instrumentalness  liveness  valence    tempo  duration_in min/ms  \
# 0               NaN    0.0849   0.8990  134.071            234596.0
# 1          0.004010    0.1010   0.5690  116.454            251733.0
# 2          0.000196    0.3940   0.7870  147.681            109667.0
# 3               NaN    0.1220   0.5690  107.033            173968.0
# 4          0.016100    0.1720   0.0918  199.060            229960.0
#
#    time_signature  Class
# 0               4      5
# 1               4     10
# 2               4      6
# 3               4      5
# 4               4     10

# %%
train['acousticness'] =

# %%
train['danceability_log'] = np.log(train['danceability'])

# %%
train['danceability_inv'] = 1 / train['danceability']

# %%
train['Popularity_log'] = train

# %%
train.head(20)
# Out:
#                      Artist Name                             Track Name  \
# 0                     Bruno Mars  That's What I Like (feat. Gucci Mane)
# 1                         Boston                           Hitch a Ride
# 2                  The Raincoats                     No Side to Fall In
# 3                           Deno             Lingo (feat. J.I & Chunkz)
# 4          Red Hot Chili Peppers      Nobody Weird Like Me - Remastered
# 5                    The Stooges      Search and Destroy - Iggy Pop Mix
# 6                  Solomon Burke                    None Of Us Are Free
# 7                   Randy Travis                      On the Other Hand
# 8      Professional Murder Music                                   Slow
# 9                    Dudu Aharon        דודו, יאללה יאללה
# 10                 Mohammed Rafi                   Meri Dosti Mera Pyar
# 11                Arctic Monkeys            The View From The Afternoon
# 12                    Eyal Golan                    קרובה אליי
# 13  Harald Lassen, Bram de Looze                     How it feels pt. 2
# 14           Buffalo Springfield                    For What It's Worth
# 15                  Elmore James                          Madison Blues
# 16                   Dudu Aharon           לא יכול בלעדייך
# 17            Velvet Two Stripes                                 Drinks
# 18                Eden Ben Zaken                           מנגינה
# 19                        DaBaby             Baby Sitter (feat. Offset)
#
#     Popularity  danceability  energy   key  loudness  mode  speechiness  \
# 0         60.0         0.854   0.564   1.0    -4.964     1       0.0485
# 1         54.0         0.382   0.814   3.0    -7.230     1       0.0406
# 2         35.0         0.434   0.614   6.0    -8.334     1       0.0525
# 3         66.0         0.853   0.597  10.0    -6.528     0       0.0555
# 4         53.0         0.167   0.975   2.0    -4.279     1       0.2160
# 5         53.0         0.235   0.977   6.0     0.878     1       0.1070
# 6         48.0         0.674   0.658   5.0    -9.647     0       0.1040
# 7         55.0         0.657   0.415   5.0    -9.915     1       0.0250
# 8         29.0         0.431   0.776  10.0    -5.403     1       0.0527
# 9         14.0         0.716   0.885   1.0    -4.348     0       0.0333
# 10        11.0         0.491   0.563   7.0    -8.588     0       0.0331
# 11        59.0         0.387   0.922   9.0    -5.192     0       0.0674
# 12        34.0         0.585   0.381   1.0    -7.622     0       0.0463
# 13        34.0         0.462   0.374  11.0   -12.069     0       0.0331
# 14        76.0         0.653   0.519   2.0   -10.164     1       0.0497
# 15        37.0         0.431   0.852   2.0    -6.522     1       0.0431
# 16        14.0         0.713   0.939   5.0    -3.609     0       0.0372
# 17        31.0         0.564   0.801   1.0    -4.730     0       0.0473
# 18        29.0         0.570   0.458   9.0    -5.935     0       0.0236
# 19        70.0         0.852   0.730   1.0    -5.803     1       0.0579
#
#     acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.017100          0.177562    0.0849   0.8990  134.071
# 1       0.001100          0.004010    0.1010   0.5690  116.454
# 2       0.486000          0.000196    0.3940   0.7870  147.681
# 3       0.021200          0.177562    0.1220   0.5690  107.033
# 4       0.000169          0.016100    0.1720   0.0918  199.060
# 5       0.003530          0.006040    0.1720   0.2410  152.952
# 6       0.404000          0.000001    0.0981   0.6770  143.292
# 7       0.175000          0.000006    0.1320   0.3470   96.030
# 8       0.000022          0.001300    0.1790   0.3180  120.857
# 9       0.061400          0.177562    0.2530   0.8330  128.043
# 10      0.957000          0.002300    0.2630   0.8430   95.558
# 11      0.004870          0.177562    0.1870   0.4170  146.478
# 12      0.435000          0.177562    0.1260   0.3220  143.876
# 13      0.949000          0.929000    0.1310   0.1740  122.939
# 14      0.406000          0.020900    0.1010   0.8220   98.883
# 15      0.564000          0.208000    0.2540   0.7940   67.601
# 16      0.110000          0.000006    0.3310   0.8800  108.034
# 17      0.002330          0.007800    0.0670   0.4010  105.010
# 18      0.502000          0.000002    0.1340   0.1900   93.088
# 19      0.021900          0.177562    0.3360   0.3940   92.506
#
#     duration_in min/ms  time_signature  Class  danceability_log  \
# 0             3.909933               1      5         -0.157824
# 1             4.195550               1     10         -0.962335
# 2             1.827783               1      6         -0.834711
# 3             2.899467               1      5         -0.158996
# 4             3.832667               1     10         -1.789761
# 5             3.468883               1      6         -1.448170
# 6             5.489783               1      2         -0.394525
# 7             3.105783               1      4         -0.420071
# 8             3.964450               1      8         -0.841647
# 9             2.734883               1      9         -0.334075
# 10            4.330450               1      3         -0.711311
# 11            3.715783               1     10         -0.949331
# 12            3.447917               1      9         -0.536143
# 13            4.440250               0      7         -0.772190
# 14            2.561550               1     10         -0.426178
# 15            2.446667               1      2         -0.841647
# 16            2.988667               1      9         -0.338274
# 17            2.571550               1     10         -0.572701
# 18            3.625483               1      9         -0.562119
# 19            2.628217               1      5         -0.160169
#
#     danceability_inv
# 0           1.170960
# 1           2.617801
# 2           2.304147
# 3           1.172333
# 4           5.988024
# 5           4.255319
# 6           1.483680
# 7           1.522070
# 8           2.320186
# 9           1.396648
# 10          2.036660
# 11          2.583979
# 12          1.709402
# 13          2.164502
# 14          1.531394
# 15          2.320186
# 16          1.402525
# 17          1.773050
# 18          1.754386
# 19          1.173709

# %%
def preprocessing(data):
    data.Popularity = data.Popularity.fillna(data.Popularity.dropna().median())
    data.key = data.key.fillna(data.key.dropna().median())
    data.instrumentalness = data.instrumentalness.fillna(data.instrumentalness.dropna().mean())
    data['time_signature'] = data['time_signature'].apply(lambda x : 1 if x ==4 else 0)
    data['duration_in min/ms'][data['duration_in min/ms'] > 30] = data['duration_in min/ms'][data['duration_in min/ms'] > 30]/60000
    return data

# %%
x = preprocessing(train)
# Out:
# <ipython-input-18-b778665c557e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['duration_in min/ms'][data['duration_in min/ms'] > 30] = data['duration_in min/ms'][data['duration_in min/ms'] > 30]/60000

# %%
corr = x.corr()

# %%
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style  type="text/css" >
# #T_faf55_row0_col0,#T_faf55_row1_col1,#T_faf55_row2_col2,#T_faf55_row3_col3,#T_faf55_row4_col4,#T_faf55_row5_col5,#T_faf55_row6_col6,#T_faf55_row7_col7,#T_faf55_row8_col8,#T_faf55_row9_col9,#T_faf55_row10_col10,#T_faf55_row11_col11,#T_faf55_row12_col12,#T_faf55_row13_col13,#T_faf55_row14_col14,#T_faf55_row15_col15,#T_faf55_row16_col16{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_faf55_row0_col1{
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }#T_faf55_row0_col2,#T_faf55_row0_col4,#T_faf55_row5_col15{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_faf55_row0_col3,#T_faf55_row4_col3,#T_faf55_row4_col12,#T_faf55_row5_col9,#T_faf55_row15_col3{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_faf55_row0_col5,#T_faf55_row1_col14,#T_faf55_row2_col3,#T_faf55_row3_col9,#T_faf55_row13_col3{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_faf55_row0_col6,#T_faf55_row8_col10,#T_faf55_row10_col14,#T_faf55_row11_col9,#T_faf55_row12_col11,#T_faf55_row13_col9,#T_faf55_row16_col5{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_faf55_row0_col7,#T_faf55_row5_col4,#T_faf55_row10_col7{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_faf55_row0_col8{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_faf55_row0_col9,#T_faf55_row1_col5{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_faf55_row0_col10,#T_faf55_row0_col14,#T_faf55_row6_col10,#T_faf55_row12_col1,#T_faf55_row13_col7{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_faf55_row0_col11,#T_faf55_row5_col13,#T_faf55_row6_col0,#T_faf55_row10_col6{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_faf55_row0_col12,#T_faf55_row1_col3,#T_faf55_row3_col6{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_faf55_row0_col13{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_faf55_row0_col15{
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }#T_faf55_row0_col16,#T_faf55_row4_col16{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_faf55_row1_col0{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_faf55_row1_col2,#T_faf55_row8_col15{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_faf55_row1_col4{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_faf55_row1_col6,#T_faf55_row8_col12{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_faf55_row1_col7,#T_faf55_row9_col15,#T_faf55_row15_col7{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_faf55_row1_col8,#T_faf55_row9_col3,#T_faf55_row11_col3{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_faf55_row1_col9,#T_faf55_row1_col11,#T_faf55_row1_col12,#T_faf55_row2_col7,#T_faf55_row3_col5,#T_faf55_row4_col8,#T_faf55_row5_col3,#T_faf55_row7_col2,#T_faf55_row7_col4,#T_faf55_row7_col9,#T_faf55_row7_col13,#T_faf55_row7_col14,#T_faf55_row8_col0,#T_faf55_row12_col6,#T_faf55_row15_col12,#T_faf55_row15_col16,#T_faf55_row16_col0,#T_faf55_row16_col1,#T_faf55_row16_col10,#T_faf55_row16_col15{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_faf55_row1_col10{
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }#T_faf55_row1_col13{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_faf55_row1_col15{
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }#T_faf55_row1_col16,#T_faf55_row2_col5,#T_faf55_row4_col5,#T_faf55_row8_col9{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_faf55_row2_col0,#T_faf55_row3_col11,#T_faf55_row9_col6,#T_faf55_row11_col12{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_faf55_row2_col1{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_faf55_row2_col4{
#             background-color:  #e26952;
#             color:  #000000;
#         }#T_faf55_row2_col6,#T_faf55_row14_col13{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_faf55_row2_col8,#T_faf55_row7_col5,#T_faf55_row10_col9,#T_faf55_row13_col11,#T_faf55_row15_col14{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_faf55_row2_col9,#T_faf55_row5_col10{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_faf55_row2_col10,#T_faf55_row5_col7,#T_faf55_row6_col4{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_faf55_row2_col11,#T_faf55_row2_col13,#T_faf55_row4_col14,#T_faf55_row8_col2{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_faf55_row2_col12,#T_faf55_row13_col8{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_faf55_row2_col14{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_faf55_row2_col15{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_faf55_row2_col16,#T_faf55_row13_col4,#T_faf55_row14_col4{
#             background-color:  #dadce0;
#             color:  #000000;
#         }#T_faf55_row3_col0,#T_faf55_row8_col11{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_faf55_row3_col1,#T_faf55_row7_col1,#T_faf55_row9_col4{
#             background-color:  #cfdaea;
#             color:  #000000;
#         }#T_faf55_row3_col2,#T_faf55_row6_col16,#T_faf55_row14_col15,#T_faf55_row15_col4,#T_faf55_row16_col2,#T_faf55_row16_col7{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_faf55_row3_col4{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_faf55_row3_col7,#T_faf55_row12_col7,#T_faf55_row16_col8{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_faf55_row3_col8,#T_faf55_row13_col14{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_faf55_row3_col10,#T_faf55_row16_col4{
#             background-color:  #9ebeff;
#             color:  #000000;
#         }#T_faf55_row3_col12,#T_faf55_row4_col6,#T_faf55_row7_col10{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_faf55_row3_col13,#T_faf55_row5_col11,#T_faf55_row6_col13,#T_faf55_row8_col14{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_faf55_row3_col14,#T_faf55_row9_col13{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_faf55_row3_col15,#T_faf55_row11_col4{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_faf55_row3_col16,#T_faf55_row4_col1{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_faf55_row4_col0,#T_faf55_row9_col14{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_faf55_row4_col2{
#             background-color:  #e0654f;
#             color:  #000000;
#         }#T_faf55_row4_col7,#T_faf55_row8_col5{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_faf55_row4_col9{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_faf55_row4_col10,#T_faf55_row5_col1,#T_faf55_row5_col2{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_faf55_row4_col11,#T_faf55_row9_col10,#T_faf55_row10_col13{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_faf55_row4_col13{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_faf55_row4_col15{
#             background-color:  #e4d9d2;
